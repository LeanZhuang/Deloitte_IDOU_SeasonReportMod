# %%
import pandas as pd

# %%
path = '/Users/zhuangyuhao/PycharmProjects/SeasonRepMod/'

# %%
df18 = pd.read_excel(path + '整合季报代码模型/整合后台数据/开发库/df18.xlsx')
df19 = pd.read_excel(path + '整合季报代码模型/整合后台数据/开发库/df19.xlsx')
df20 = pd.read_excel(path + '整合季报代码模型/整合后台数据/开发库/df20.xlsx')
df21 = pd.read_excel(path + '整合季报代码模型/整合后台数据/开发库/df21.xlsx')
df22 = pd.read_excel(path + '整合季报代码模型/整合后台数据/开发库/df22.xlsx')

# %%
df_total = pd.concat([df18, df19, df20, df21, df22])
df_total.drop(columns="Unnamed: 0", inplace=True)

# %%
# df_total.to_excel(path + '整合季报代码模型/整合后台数据/开发库/df_202122.xlsx')

# %%
df_total
# Out:
#                      BASIC_entity_name BASIC_code BASIC_industry  BASIC_year  \
# 0      1957 & Co.(Hospitality) Limited    8495.HK           M002         NaN
# 1                         360鲁大师控股有限公司    3601.HK           M014         NaN
# 2                           361度国际有限公司    1361.HK           M007         NaN
# 3                          A8新媒体集团有限公司    0800.HK           M014         NaN
# 4                        ASMPT Limited    0522.HK           M014         NaN
# ...                                ...        ...            ...         ...
# 18872                     龙芯中科技术股份有限公司  688047.SH           M001      2022.0
# 18873                     龙芯中科技术股份有限公司  688047.SH           M001      2022.0
# 18874                    龙记(百慕达)集团有限公司    0255.HK           M008         NaN
# 18875                          龙资源有限公司    1712.HK           M003         NaN
# 18876                       龙辉国际控股有限公司    1007.HK           M002         NaN
#
# ...

# %%
df_total[df_total.BASIC_entity_name == '协鑫智慧能源(苏州)有限公司']
# Out:
#      BASIC_entity_name BASIC_code BASIC_industry  BASIC_year  BASIC_quarter  \
# 6160    协鑫智慧能源(苏州)有限公司        NaN           M004         NaN            NaN
# 6161    协鑫智慧能源(苏州)有限公司  112624.SZ           M004         NaN            NaN
# 6160    协鑫智慧能源(苏州)有限公司        NaN           M004         NaN            NaN
# 6161    协鑫智慧能源(苏州)有限公司  112624.SZ           M004         NaN            NaN
# 6160    协鑫智慧能源(苏州)有限公司        NaN           M004         NaN            NaN
# 6161    协鑫智慧能源(苏州)有限公司  112624.SZ           M004         NaN            NaN
# 5013    协鑫智慧能源(苏州)有限公司        NaN           M004         NaN            NaN
# 5014    协鑫智慧能源(苏州)有限公司  112624.SZ           M004         NaN            NaN
# 5048    协鑫智慧能源(苏州)有限公司        NaN           M004      2022.0            1.0
# 5049    协鑫智慧能源(苏州)有限公司        NaN           M004      2022.0            2.0
# 5050    协鑫智慧能源(苏州)有限公司  112624.SZ           M004      2022.0            1.0
# ...
